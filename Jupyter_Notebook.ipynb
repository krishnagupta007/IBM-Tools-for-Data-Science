# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# <html>
# <h1>
# Data Science Tools & Ecosystem
# </h1>
# </html>

# %% [markdown]
# <html>
# <p>
# In this notebook, Data Science tools & Ecosystem are summarized
# </p>
# </html>

# %% [markdown]
# <html>
# <body>
#     <h4>Some of the popular languages that Data scientists use are:</h4>
#     <ol type="1">
#         <li> Python </li>
#         <li> R </li>
#         <li> Scala </li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# <html>
# <body>
#     <h4>Some of the commonly used libraries by Data Scientists include :</h4>
#     <ol type="1">
#         <li> TensorFlow </li>
#         <li> Pandas </li>
#         <li> NumPy </li>
#     </ol>
# </body>
# </html>

# %% [markdown]
# <html>
# <body>
#     <table>
#         <tr>
#             <th>
#                 Data Science Tools
#             </th>
#         </tr>
#         <tr>
#             <td>
#                 MySQL
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 TensorFLow Lite
#             </td>
#         </tr>
#         <tr>
#             <td>
#                 Apache AirFlow
#             </td>
#         </tr>
#     </table>
# </body>
# </html>

# %% [markdown]
# <html>
# <h3>
# Below are few examples of evaluating arithmetic expressions in Python.
# </h3>
# </html>

# %%
(3*4)+5
